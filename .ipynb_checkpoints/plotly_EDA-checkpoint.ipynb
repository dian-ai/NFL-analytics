# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.patches as patches


import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px

import statsmodels.api as sm
import plotly.graph_objs as go
#sns.set(rc = {'figure.figsize':(12,7)})
#plt.style.use(['dark_background', 'presentation'])

# %%
df_players = pd.read_csv('players_new.csv')

# %%
df_players.head()
# Out:
#      nflId  height  weight   birthDate             collegeName position  \
# 0  2539334      72     190  1990-09-10              Washington       CB
# 1  2539653      70     186  1988-11-01  Southeastern Louisiana       CB
# 2  2543850      69     186  1991-12-18                  Purdue       SS
# 3  2555162      73     227  1994-11-04         Louisiana State      MLB
# 4  2555255      75     232  1993-07-01               Minnesota      OLB
#
#           displayName team_role
# 0     Desmond Trufant   Defense
# 1       Robert Alford   Defense
# 2       Ricardo Allen   Defense
# 3         Deion Jones   Defense
# 4  De'Vondre Campbell   Defense

# %%
df_college = df_players.groupby(['collegeName', 'team_role'], as_index = False)[['nflId']].count()

# %%
df_college.head(3)
# Out:
#          collegeName team_role  nflId
# 0  Abilene Christian   Offense      2
# 1              Akron   Defense      2
# 2            Alabama   Defense     21

# %%
barchart_college = px.bar(
data_frame = df_college,
x = 'collegeName',
y = 'nflId',
color = 'team_role',
opacity = 0.9,
orientation = 'v',
barmode = 'relative',
color_discrete_map = {'Offense': 'gray', 'Defense': 'red', 'Special': 'blue'})

# %%
#barchart_college.update_layout(axis={'categoryorder':'total descending'})
barchart_college

barchart_college.update_layout(xaxis={'categoryorder':'total descending'}, autosize = False, width =1000, height =500)
# Out:
# <div>                            <div id="283638b5-50be-4297-9421-4a638215364f" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("283638b5-50be-4297-9421-4a638215364f")) {                    Plotly.newPlot(                        "283638b5-50be-4297-9421-4a638215364f",                        [{"alignmentgroup": "True", "hovertemplate": "team_role=Offense<br>collegeName=%{x}<br>nflId=%{y}<extra></extra>", "legendgroup": "Offense", "marker": {"color": "gray", "opacity": 0.9}, "name": "Offense", "offsetgroup": "Offense", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Abilene Christian", "Alabama", "Alabama State", "Alabama-Birmingham", "Albany, N.Y.", "Alcorn State", "Appalachian State", "Arizona", "Arizona State"
# ...

# %%
#colleges = ['Oklahoma', 'Alabama']
birthyear_fig = px.histogram(df_players, x="birthDate", labels = {'birthDate': 'Year of Birth'})
birthyear_fig.update_layout(autosize = False, width =1000, height =500)
birthyear_fig.show()
# Out:
# <div>                            <div id="49e5463e-0be5-4136-b18c-ea15f099e9fe" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49e5463e-0be5-4136-b18c-ea15f099e9fe")) {                    Plotly.newPlot(                        "49e5463e-0be5-4136-b18c-ea15f099e9fe",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Year of Birth=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["1990-09-10", "1988-11-01", "1991-12-18", "1994-11-04", "1993-07-01", "1995-07-26", "1992-10-20", "1986-08-01", "1989-01-20", "1990-11-10", "1993-06-15", "1993-05-24", "1993-04-10", "1992-07-08", "1983-0
# ...

# %%
#import plotly.graph_objects as go

#import numpy as np

#x0 = np.random.randn(500)
# Add 1 to shift the mean of the Gaussian distribution
#x1 = np.random.randn(500) + 1

#fig = go.Figure()
#fig.add_trace(go.Histogram(x=x0))
#fig.add_trace(go.Histogram(x=x1))

# Overlay both histograms
#fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
#fig.update_traces(opacity=0.75)
#fig.show()

# %%
height_weight_scatter = px.scatter(data_frame = df_players, x = 'weight', y = 'height', 
                                    color="team_role", symbol = 'position', facet_col = 'team_role')
height_weight_scatter.update_layout(autosize = False, width =1000, height =500)
# Out:
# <div>                            <div id="be297d7f-faab-494e-8351-29f7e5c33d4c" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be297d7f-faab-494e-8351-29f7e5c33d4c")) {                    Plotly.newPlot(                        "be297d7f-faab-494e-8351-29f7e5c33d4c",                        [{"hovertemplate": "team_role=Defense<br>position=CB<br>weight=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Defense, CB", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Defense, CB", "showlegend": true, "type": "scattergl", "x": [190, 186, 211, 193, 191, 181, 205, 209, 210, 185, 197, 193, 192, 192, 178, 193, 190, 196, 193, 191, 195, 197, 184, 188, 204, 190, 196, 205, 193, 185, 190, 195, 190, 185, 192, 200, 203, 188, 185, 
# ...

# %%
#height_weight_scatter

# %%
height_weight_distribution = px.scatter(data_frame = df_players, x = 'weight', y = 'height', 
                                    color="team_role", symbol = 'team_role', 
                                  marginal_x = 'rug', marginal_y = 'box')

# %%
height_weight_distribution.update_layout(autosize = False, width =1200, height =600)
# Out:
# <div>                            <div id="e826c62d-f427-4cfc-9b80-dea07a64cd1e" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e826c62d-f427-4cfc-9b80-dea07a64cd1e")) {                    Plotly.newPlot(                        "e826c62d-f427-4cfc-9b80-dea07a64cd1e",                        [{"hovertemplate": "team_role=Defense<br>weight=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Defense", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Defense", "showlegend": true, "type": "scattergl", "x": [190, 186, 186, 227, 232, 216, 211, 246, 230, 190, 204, 195, 236, 193, 191, 230, 230, 181, 196, 215, 205, 209, 210, 195, 211, 250, 272, 185, 261, 197, 245, 197, 191, 193, 192, 223, 250, 192, 265, 207, 227, 205, 205, 244
# ...

# %%
height_weight_distribution_animation = px.scatter(data_frame = df_players, x = 'weight', y = 'height', 
                                    color="team_role", symbol = 'team_role', 
                                  animation_frame = 'team_role', 
                                       range_x = [150,350], range_y = [60,80],
                                       category_orders = {'team_role': ['Special', 'Offense', 'Defense']})

height_weight_distribution_animation.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000
height_weight_distribution_animation.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 700

# %%
height_weight_distribution_animation
# Out:
# <div>                            <div id="6f4f4b02-a16c-4283-b7fc-913bba6a84fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f4f4b02-a16c-4283-b7fc-913bba6a84fa")) {                    Plotly.newPlot(                        "6f4f4b02-a16c-4283-b7fc-913bba6a84fa",                        [{"hovertemplate": "team_role=Special<br>weight=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Special", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Special", "orientation": "v", "showlegend": true, "type": "scatter", "x": [214, 260, 207, 208, 240, 235, 241, 235, 255, 210, 235, 208, 240, 205, 243, 215, 200, 224, 250, 213, 185, 195, 245, 222, 233, 258, 201, 211, 220, 235], "xaxis": "x", "y": [74, 76, 73, 78, 75, 74, 77, 76,
# ...

# %%
import zipfile

zf = zipfile.ZipFile('/home/skywalker/Desktop/final_project/plays.csv.zip') 
df_plays = pd.read_csv(zf.open('plays.csv'))

df_games = pd.read_csv('games.csv')

# %%
#df_plays.columns, df_games.columns

# %%
#adding the necessary columns into plays
df_plays['week'] = df_plays['gameId'].map(df_games.set_index('gameId')['week'])
df_plays['homeTeam'] =df_plays['gameId'].map(df_games.set_index('gameId')['homeTeamAbbr'])
df_plays['guestTeam'] =df_plays['gameId'].map(df_games.set_index('gameId')['visitorTeamAbbr'])

# %%
df_plays.head(3)
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
#
#    yardlineNumber  ... penaltyCodes penaltyJerseyNumbers  passResult  \
# 0              20  ...          NaN                  NaN           C
# 1              39  ...          NaN                  NaN           I
# 2              39  ...          NaN                  NaN           I
#
#    offensePlayResult playResult       epa  isDefensivePI  week homeTeam  \
# ...

# %%
#df_week1 = pd.DataFrame(df_plays.loc[df_plays['week']==1])

# %%
#df_week1 = df_week1[['gameId','possessionTeam', 'playType', 'offenseFormation', 'personnelO', 
#'defendersInTheBox', 'numberOfPassRushers', 'personnelD', 'typeDropback',
#'passResult', 'offensePlayResult']]

# %%
#df_week1.gameId.unique()

# %%
#s = df_plays.groupby('week')['gameId'].unique()

# %%
#len(df_week1.gameId.unique()), df_week1.possessionTeam.unique()

# %%
#list_matches = df_week1.groupby('gameId')['possessionTeam'].unique().tolist()
#list_matches=list_matches.tolist()
#list_matches[0] ,str(3)

# %%
#y_week = df_plays.loc[df_plays['week']== 1, ['gameId', 'possessionTeam']]
#y_week

# %%
list =range(1,18)

grand_list = []
for i in list:
    name = 'week'+str(i)
    y_week = df_plays.loc[df_plays['week']== i, ['gameId', 'homeTeam', 'guestTeam']]
    y_week['matches'] = '['+ y_week['homeTeam']+ ','+ y_week['guestTeam']+']'
    num_games = str(len(y_week['gameId'].unique()))
    #y_matches = np.array(y_week.groupby('gameId')['possessionTeam'].unique().tolist())
    y_matches = np.array(y_week['matches'].unique().tolist())
    data =[name, num_games, y_matches]
    grand_list.append(data)

# %%
#from operator import itemgetter

#def Extract(lst):

    #return list( map(itemgetter(0), lst )) 
#week_grand_list = list( map(itemgetter(0), grand_list ))
#week_grand_list
list_week = [item[0] for item in grand_list]
list_games = [item[1] for item in grand_list]
list_matches = [item[2] for item in grand_list]

#tuple_matches = [tuple(l) for l in list_matches]

# %%
list_matches[0]
# Out:
# array(['[PHI,ATL]', '[CLE,PIT]', '[IND,CIN]', '[MIA,TEN]', '[BAL,BUF]',
#        '[NE,HOU]', '[NYG,JAX]', '[NO,TB]', '[ARI,WAS]', '[CAR,DAL]',
#        '[GB,CHI]', '[DET,NYJ]', '[OAK,LA]'], dtype='<U9')

# %%
#values = ['Weeks', 'Number of Matches', 'Matches between teams']
#values

# %%
#list_matches

# %%
#list_matches[0]

# %%
fig = go.Figure(data = go.Table(
    columnorder= [1,2,3],
    columnwidth = [90,90,1300],
    
    header = dict(values = ['Weeks', 'Number of Matches', 'Matches between teams'], align = 'center', height = 40),
    cells = dict(values = [list_week, list_games, list_matches], align = 'center', height = 40)
))

#fig.show()
#fig.update_layout(style_data={
#    'whiteSpace':'normal', 'height': 'auto'
#})
fig.layout.width = 1300
fig.show()
# Out:
# <div>                            <div id="0401cb11-9406-4aae-8267-148f28807ec8" class="plotly-graph-div" style="height:525px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0401cb11-9406-4aae-8267-148f28807ec8")) {                    Plotly.newPlot(                        "0401cb11-9406-4aae-8267-148f28807ec8",                        [{"cells": {"align": "center", "height": 40, "values": [["week1", "week2", "week3", "week4", "week5", "week6", "week7", "week8", "week9", "week10", "week11", "week12", "week13", "week14", "week15", "week16", "week17"], ["13", "16", "16", "15", "15", "15", "14", "14", "13", "14", "13", "15", "16", "16", "16", "16", "16"], [["[PHI,ATL]", "[CLE,PIT]", "[IND,CIN]", "[MIA,TEN]", "[BAL,BUF]", "[NE,HOU]", "[NYG,JAX]", "[NO,TB]", "[ARI,WAS]", "[CAR,DAL]", "[GB,CHI]", "[
# ...

# %%
#grand_list[0:1]

# %%
#def player_teams(df):
#    y = {}
#    for i in ['Offense', 'Defense', 'Special']:
#        name = 'y'+'_'+ i
#        y_ax = df.loc[df['team_role']== i, 'nflId']
 #       case ={ name : y_ax}
#        y.update(case)
 #   return y

# %%
#list_games_week1 = df_week1['gameId'].unique()

# %%
#df_week1 = df_week1[['gameId','possessionTeam', 'playType', 'offenseFormation', 'personnelO', 
#'defendersInTheBox', 'numberOfPassRushers', 'personnelD', 'typeDropback',
#'passResult', 'offensePlayResult']]

# %%
df_saving = df_plays[['week', 'gameId','possessionTeam', 'playType', 'offenseFormation', 'personnelO', 
'defendersInTheBox', 'numberOfPassRushers', 'personnelD', 'typeDropback',
'passResult', 'offensePlayResult', 'homeTeam', 'guestTeam']].copy()
df_saving['matches'] = '['+ df_saving['homeTeam']+ ' , '+ df_saving['guestTeam']+']'

# %%
df_saving.to_csv('dash_plays.csv')

# %%
df = df_plays[['week', 'gameId','possessionTeam', 'playType', 'offenseFormation', 'personnelO', 
'defendersInTheBox', 'numberOfPassRushers', 'personnelD', 'typeDropback',
'passResult', 'offensePlayResult', 'homeTeam', 'guestTeam']]
df['matches'] = '['+ df['homeTeam']+ ' , '+ df['guestTeam']+']'
df = df.groupby(['week', 'matches', 'playType'])[['playType']].count()
# Out:
# <ipython-input-52-5359485ab77e>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = df.add_suffix('_Count').reset_index()

# %%
df.head()
# Out:
#    week      matches           playType  playType_Count
# 0     1  [ARI , WAS]     play_type_pass              64
# 1     1  [ARI , WAS]     play_type_sack               5
# 2     1  [ARI , WAS]  play_type_unknown               4
# 3     1  [BAL , BUF]     play_type_pass              68
# 4     1  [BAL , BUF]     play_type_sack               8

# %%
playtype_pichart = px.pie(
data_frame = df, values = 'playType_Count', names= 'playType', color = 'playType', hole = 0.3)

# %%
playtype_pichart
# Out:
# <div>                            <div id="f400db26-bd6e-4c53-a08a-15709217b5da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f400db26-bd6e-4c53-a08a-15709217b5da")) {                    Plotly.newPlot(                        "f400db26-bd6e-4c53-a08a-15709217b5da",                        [{"customdata": [["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_type_pass"], ["play_type_sack"], ["play_type_unknown"], ["play_typ
# ...

# %%
#df['playType'].unique()

# %% [markdown]
# lets show how we can plot for each game the scores ( do it later )

# %%
# lets see if I can create sub plots showing each week the number of playtypes on bar chart

# %%
#barchart_playtype = px.bar(
#data_frame = df,
#x = 'playType',
#y = 'playType_Count',
#color = 'playType',
#opacity = 0.9,
#orientation = 'v',
#barmode = 'relative',
#facet_col = 'week',
#    facet_col_wrap = 3
#)
#barchart_playtype.update_layout(height = 1200)

# %%
barchart_playtype = px.bar(
data_frame = df,
x = 'week',
y = 'playType_Count',
color = 'playType',
opacity = 0.9,
orientation = 'v',
#barmode = 'group',
facet_row = 'playType',
color_discrete_sequence =['thistle ', 'mediumslateblue', 'orangered'],
hover_name = 'matches',
labels = {'playType_Count': 'number of times play-type repeated in week', 'playType': 'play-type chosen by teams'},
title = 'stacked bar chart for playtype based on each game, each week')
barchart_playtype.update_layout(height = 1200)
barchart_playtype.update_yaxes(matches = None)
# Out:
# <div>                            <div id="73835bee-1a61-49df-8007-b923845cc6d9" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73835bee-1a61-49df-8007-b923845cc6d9")) {                    Plotly.newPlot(                        "73835bee-1a61-49df-8007-b923845cc6d9",                        [{"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>play-type chosen by teams=play_type_pass<br>week=%{x}<br>number of times play-type repeated in week=%{y}<extra></extra>", "hovertext": ["[ARI , WAS]", "[BAL , BUF]", "[CAR , DAL]", "[CLE , PIT]", "[DET , NYJ]", "[GB , CHI]", "[IND , CIN]", "[MIA , TEN]", "[NE , HOU]", "[NO , TB]", "[NYG , JAX]", "[OAK , LA]", "[PHI , ATL]", "[ATL , CAR]", "[BUF , LAC]", "[CHI , SEA]", "[CIN , BAL]", "[DAL , 
# ...

# %%
##dash practice:

df_dash = df_plays[['week', 'gameId','possessionTeam', 'playType', 'offenseFormation', 'personnelO', 
'defendersInTheBox', 'numberOfPassRushers', 'personnelD', 'typeDropback',
'passResult', 'offensePlayResult', 'homeTeam', 'guestTeam']].copy()
df_dash['matches'] = '['+ df_dash['homeTeam']+ ' , '+ df_dash['guestTeam']+']'

# %%
df_dash.head()
# Out:
#    week      gameId possessionTeam        playType offenseFormation  \
# 0     1  2018090600            ATL  play_type_pass           I_FORM
# 1     1  2018090600            ATL  play_type_pass       SINGLEBACK
# 2     1  2018090600            ATL  play_type_pass          SHOTGUN
# 3     1  2018090600            ATL  play_type_pass          SHOTGUN
# 4     1  2018090600            ATL  play_type_pass          SHOTGUN
#
#          personnelO  defendersInTheBox  numberOfPassRushers        personnelD  \
# 0  2 RB, 1 TE, 2 WR                7.0                  4.0  4 DL, 2 LB, 5 DB
# 1  1 RB, 1 TE, 3 WR                7.0                  4.0  4 DL, 2 LB, 5 DB
# 2  2 RB, 1 TE, 2 WR                6.0                  4.0  4 DL, 2 LB, 5 DB
# 3  1 RB, 1 TE, 3 WR                6.0                  5.0  4 DL, 1 LB, 6 DB
# 4  2 RB, 3 TE, 0 WR                8.0                  6.0  6 DL, 3 LB, 2 DB
#
#             typeDropback passResult  offensePlayResult homeTeam guestTeam  \
# ...

# %%
df_dash_week1 = df_dash.loc[df_dash['week'] == 1]

df_dash_week1
# Out:
#        week      gameId possessionTeam           playType offenseFormation  \
# 0         1  2018090600            ATL     play_type_pass           I_FORM
# 1         1  2018090600            ATL     play_type_pass       SINGLEBACK
# 2         1  2018090600            ATL     play_type_pass          SHOTGUN
# 3         1  2018090600            ATL     play_type_pass          SHOTGUN
# 4         1  2018090600            ATL     play_type_pass          SHOTGUN
# ...     ...         ...            ...                ...              ...
# 18644     1  2018091000            NYJ  play_type_unknown            EMPTY
# 18645     1  2018091000            DET  play_type_unknown          SHOTGUN
# 18646     1  2018091001            OAK  play_type_unknown          SHOTGUN
# 18647     1  2018091001             LA  play_type_unknown          SHOTGUN
# 18648     1  2018091001             LA  play_type_unknown       SINGLEBACK
#
#              personnelO  defendersInTheBox  numberOfPassRushers  \
# ...

# %%
df_dash_week1.to_csv('pie_week1.csv')

# %%
df_dash_week1_new = df_dash_week1.groupby(['matches', 'possessionTeam', 'passResult'])[['passResult']].count()

# %%
df_dash_week1_new = df_dash_week1_new.add_suffix('_Count').reset_index()

# %%
df_dash_week1_new.tail(-3)
# Out:
#         matches possessionTeam passResult  passResult_Count
# 3   [ARI , WAS]            ARI          S                 2
# 4   [ARI , WAS]            WAS          C                22
# 5   [ARI , WAS]            WAS          I                11
# 6   [ARI , WAS]            WAS          S                 3
# 7   [BAL , BUF]            BAL          C                24
# ..          ...            ...        ...               ...
# 88  [PHI , ATL]            ATL          S                 4
# 89  [PHI , ATL]            PHI          C                22
# 90  [PHI , ATL]            PHI          I                16
# 91  [PHI , ATL]            PHI         IN                 1
# 92  [PHI , ATL]            PHI          S                 2
#
# [90 rows x 4 columns]

# %%
playtype_pichart = px.pie(
data_frame = df_dash_week1_new, values = 'passResult_Count', names= 'passResult', color = 'passResult',
 hole = 0.3)

playtype_pichart
# Out:
# <div>                            <div id="de16f224-c80b-4ca3-98b9-35700954b187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de16f224-c80b-4ca3-98b9-35700954b187")) {                    Plotly.newPlot(                        "de16f224-c80b-4ca3-98b9-35700954b187",                        [{"customdata": [["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"], ["C"], ["I"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"], ["C"], ["I"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["C"], ["I"], ["IN"], ["S"], ["C"], ["I"]
# ...

# %%
df_dash2_week1 = df_dash_week1_new.loc[df_dash_week1_new['matches'] == '[ARI , WAS]']
df_dash2_week1
# Out:
#        matches possessionTeam passResult  passResult_Count
# 0  [ARI , WAS]            ARI          C                20
# 1  [ARI , WAS]            ARI          I                14
# 2  [ARI , WAS]            ARI         IN                 1
# 3  [ARI , WAS]            ARI          S                 2
# 4  [ARI , WAS]            WAS          C                22
# 5  [ARI , WAS]            WAS          I                11
# 6  [ARI , WAS]            WAS          S                 3

# %%
passres_pichart = px.pie(
data_frame = df_dash2_week1, values = 'passResult_Count', names= 'passResult', color = 'passResult',
 hole = 0.3)

passres_pichart
# Out:
# <div>                            <div id="76a0aa48-5e4d-4ea1-9895-bcd618719c55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76a0aa48-5e4d-4ea1-9895-bcd618719c55")) {                    Plotly.newPlot(                        "76a0aa48-5e4d-4ea1-9895-bcd618719c55",                        [{"customdata": [["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hovertemplate": "passResult=%{customdata[0]}<br>passResult_Count=%{value}<extra></extra>", "labels": ["C", "I", "IN", "S", "C", "I", "S"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#ab63fa"]}, "name": "", "showlegend": true, "type": "pie", "values": [20, 14, 1, 2, 22, 11, 3
# ...

# %%
#[PHI , ATL]
df_dash3_week1 =df_dash_week1_new.loc[df_dash_week1_new['matches'] == '[BAL , BUF]']
df_dash3_week1
# Out:
#         matches possessionTeam passResult  passResult_Count
# 7   [BAL , BUF]            BAL          C                24
# 8   [BAL , BUF]            BAL          I                13
# 9   [BAL , BUF]            BAL          S                 2
# 10  [BAL , BUF]            BUF          C                11
# 11  [BAL , BUF]            BUF          I                21
# 12  [BAL , BUF]            BUF         IN                 2
# 13  [BAL , BUF]            BUF          S                 6

# %%
passres2_pichart = px.pie(
data_frame = df_dash2_week1, values = 'passResult_Count', names= 'passResult', color = 'passResult',
 hole = 0.3)
passres2_pichart
# Out:
# <div>                            <div id="bfea66fe-d480-4259-87ca-0d934e886017" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfea66fe-d480-4259-87ca-0d934e886017")) {                    Plotly.newPlot(                        "bfea66fe-d480-4259-87ca-0d934e886017",                        [{"customdata": [["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hovertemplate": "passResult=%{customdata[0]}<br>passResult_Count=%{value}<extra></extra>", "labels": ["C", "I", "IN", "S", "C", "I", "S"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#ab63fa"]}, "name": "", "showlegend": true, "type": "pie", "values": [20, 14, 1, 2, 22, 11, 3
# ...

# %%
df_dash3_week1_new = df_dash_week1.groupby(['matches', 'possessionTeam', 'passResult'])[['passResult']].count()

# %%
df_dash3_week1_new
# Out:
#                                        passResult
# matches     possessionTeam passResult
# [ARI , WAS] ARI            C                   20
#                            I                   14
#                            IN                   1
#                            S                    2
#             WAS            C                   22
# ...                                           ...
# [PHI , ATL] ATL            S                    4
#             PHI            C                   22
#                            I                   16
#                            IN                   1
#                            S                    2
#
# [93 rows x 1 columns]

# %%
#transform this dataframe based on matches column turning into column themselves and 
df_dash4_week1_new = df_dash3_week1_new.add_suffix('_Count').reset_index()
df_dash4_week1_new.head(5)
# Out:
#        matches possessionTeam passResult  passResult_Count
# 0  [ARI , WAS]            ARI          C                20
# 1  [ARI , WAS]            ARI          I                14
# 2  [ARI , WAS]            ARI         IN                 1
# 3  [ARI , WAS]            ARI          S                 2
# 4  [ARI , WAS]            WAS          C                22

# %%
exam = df_dash4_week1_new.groupby(['matches', 'passResult'])['passResult_Count'].sum()
exam = exam.reset_index()
exam.head()
# Out:
#        matches passResult  passResult_Count
# 0  [ARI , WAS]          C                42
# 1  [ARI , WAS]          I                25
# 2  [ARI , WAS]         IN                 1
# 3  [ARI , WAS]          S                 5
# 4  [BAL , BUF]          C                35

# %%
exam_new = exam.set_index(['matches', 'passResult']).unstack('matches').reset_index()
exam_new.head()
# Out:
#         passResult passResult_Count                                      \
# matches                 [ARI , WAS] [BAL , BUF] [CAR , DAL] [CLE , PIT]
# 0                C             42.0        35.0        36.0        38.0
# 1                I             25.0        34.0        23.0        40.0
# 2               IN              1.0         2.0         NaN         5.0
# 3                S              5.0         8.0         9.0        11.0
#
#                                                                              \
# matches [DET , NYJ] [GB , CHI] [IND , CIN] [MIA , TEN] [NE , HOU] [NO , TB]
# 0              46.0       47.0        60.0        40.0       43.0      58.0
# 1              24.0       26.0        22.0        22.0       31.0      19.0
# 2               6.0        1.0         2.0         5.0        2.0       NaN
# 3               2.0        8.0         5.0         1.0        5.0       1.0
#
#
# matches [NYG , JAX] [OAK , LA] [PHI , ATL]
# ...

# %%
exam_new.columns
# Out:
# MultiIndex([(      'passResult',            ''),
#             ('passResult_Count', '[ARI , WAS]'),
#             ('passResult_Count', '[BAL , BUF]'),
#             ('passResult_Count', '[CAR , DAL]'),
#             ('passResult_Count', '[CLE , PIT]'),
#             ('passResult_Count', '[DET , NYJ]'),
#             ('passResult_Count',  '[GB , CHI]'),
#             ('passResult_Count', '[IND , CIN]'),
#             ('passResult_Count', '[MIA , TEN]'),
#             ('passResult_Count',  '[NE , HOU]'),
#             ('passResult_Count',   '[NO , TB]'),
#             ('passResult_Count', '[NYG , JAX]'),
#             ('passResult_Count',  '[OAK , LA]'),
#             ('passResult_Count', '[PHI , ATL]')],
#            names=[None, 'matches'])

# %%
exam_new = exam_new.set_index(['passResult'])
exam_new.columns = exam_new.columns.droplevel(0)
exam_new = exam_new.reset_index()

exam_new.head()
# Out:
# matches passResult  [ARI , WAS]  [BAL , BUF]  [CAR , DAL]  [CLE , PIT]  \
# 0                C         42.0         35.0         36.0         38.0
# 1                I         25.0         34.0         23.0         40.0
# 2               IN          1.0          2.0          NaN          5.0
# 3                S          5.0          8.0          9.0         11.0
#
# matches  [DET , NYJ]  [GB , CHI]  [IND , CIN]  [MIA , TEN]  [NE , HOU]  \
# 0               46.0        47.0         60.0         40.0        43.0
# 1               24.0        26.0         22.0         22.0        31.0
# 2                6.0         1.0          2.0          5.0         2.0
# 3                2.0         8.0          5.0          1.0         5.0
#
# matches  [NO , TB]  [NYG , JAX]  [OAK , LA]  [PHI , ATL]
# 0             58.0         41.0        47.0         43.0
# 1             19.0         31.0        25.0         38.0
# 2              NaN          2.0         3.0          2.0
# ...

# %%
exam_new.to_csv('matches_week1_pie.csv')

# %%
df_dash5_week1_new = df_dash4_week1_new.groupby(['matches', 'possessionTeam', 'passResult'])[['passResult_Count']].sum()

df_dash5_week1_new = df_dash5_week1_new.add_suffix('_sumed').reset_index()
df_dash5_week1_new
# Out:
#         matches possessionTeam passResult  passResult_Count_sumed
# 0   [ARI , WAS]            ARI          C                      20
# 1   [ARI , WAS]            ARI          I                      14
# 2   [ARI , WAS]            ARI         IN                       1
# 3   [ARI , WAS]            ARI          S                       2
# 4   [ARI , WAS]            WAS          C                      22
# ..          ...            ...        ...                     ...
# 88  [PHI , ATL]            ATL          S                       4
# 89  [PHI , ATL]            PHI          C                      22
# 90  [PHI , ATL]            PHI          I                      16
# 91  [PHI , ATL]            PHI         IN                       1
# 92  [PHI , ATL]            PHI          S                       2
#
# [93 rows x 4 columns]

# %%
passres2_pichart = px.pie(
data_frame = df_dash4_week1_new.loc[df_dash4_week1_new['matches']=='[ARI , WAS]'], values = 'passResult_Count', names= 'passResult', color = 'passResult',
 hole = 0.3)
passres2_pichart
# Out:
# <div>                            <div id="263a7419-a3c4-4030-b5ac-e6f056d71e12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("263a7419-a3c4-4030-b5ac-e6f056d71e12")) {                    Plotly.newPlot(                        "263a7419-a3c4-4030-b5ac-e6f056d71e12",                        [{"customdata": [["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["S"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hovertemplate": "passResult=%{customdata[0]}<br>passResult_Count=%{value}<extra></extra>", "labels": ["C", "I", "IN", "S", "C", "I", "S"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#ab63fa"]}, "name": "", "showlegend": true, "type": "pie", "values": [20, 14, 1, 2, 22, 11, 3
# ...

# %%
#df_dash4_week1_new.loc[df_dash4_week1_new['matches']=='[PHI , ATL]']

passres3_pichart = px.pie(
data_frame = df_dash4_week1_new.loc[df_dash4_week1_new['matches']=='[PHI , ATL]'], values = 'passResult_Count', names= 'passResult', color = 'passResult',
 hole = 0.3)
passres3_pichart
# Out:
# <div>                            <div id="c96a3ded-6558-47d9-8166-f3fff8405cde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c96a3ded-6558-47d9-8166-f3fff8405cde")) {                    Plotly.newPlot(                        "c96a3ded-6558-47d9-8166-f3fff8405cde",                        [{"customdata": [["C"], ["I"], ["IN"], ["S"], ["C"], ["I"], ["IN"], ["S"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hovertemplate": "passResult=%{customdata[0]}<br>passResult_Count=%{value}<extra></extra>", "labels": ["C", "I", "IN", "S", "C", "I", "IN", "S"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#00cc96", "#ab63fa"]}, "name": "", "showlegend": true, "type": "pie", "values":
# ...

# %%
barchart_paassres = px.bar(
data_frame = df_dash_week1_new,
x = 'matches',
y = 'passResult_Count',
color = 'passResult',
opacity = 0.9,
orientation = 'v',
barmode = 'group',
#facet_row = 'playType',
color_discrete_sequence =['thistle ', 'mediumslateblue', 'orangered'])
#hover_name = 'matches',
#labels = {'playType_Count': 'number of times play-type repeated in week', 'playType': 'play-type chosen by teams'},
#title = 'stacked bar chart for playtype based on each game, each week')
#barchart_playtype.update_layout(height = 1200)
#barchart_playtype.update_yaxes(matches = None)

# %%
barchart_paassres
# Out:
# <div>                            <div id="0e5c3ff0-6863-4ce2-b73f-874ed41fc1ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e5c3ff0-6863-4ce2-b73f-874ed41fc1ae")) {                    Plotly.newPlot(                        "0e5c3ff0-6863-4ce2-b73f-874ed41fc1ae",                        [{"alignmentgroup": "True", "hovertemplate": "passResult=C<br>matches=%{x}<br>passResult_Count=%{y}<extra></extra>", "legendgroup": "C", "marker": {"color": "thistle ", "opacity": 0.9}, "name": "C", "offsetgroup": "C", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["[ARI , WAS]", "[ARI , WAS]", "[BAL , BUF]", "[BAL , BUF]", "[CAR , DAL]", "[CAR , DAL]", "[CLE , PIT]", "[CLE , PIT]", "[DET , NYJ]", "[DET , NYJ]", "[GB , CHI]", 
# ...

# %%
df_iris = px.data.iris()

df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...
